# %%
from control import *
from math import *
from numpy import *
from matplotlib.pyplot import *
from control_plotly import rlocus
# %matplotlib notebook
g=tf(2,[1,3,2,0])
gc=tf(2,[1,3,2,2])

# %%
g
rlocus(g)

# %%
rlocus(gc)
