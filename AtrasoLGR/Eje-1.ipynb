# %% [markdown]
# # Control Clasico
# ## Compensador en atraso LGR
# **Ejemplo 1**
# La función de transferencia de lazo abierto de un sistema de control es
#
# $G(s)=\frac{4}{s(s+2)}$
#
# Se desea que el sistema cumpla con las siguientes
# $\zeta=0.5 seg^{-1}$ y la relación de amortiguamiento $w_n=4$ rad/seg

# %%
from control import *
from numpy import *
from matplotlib.pyplot import *
# %matplotlib notebook
g = tf([4], [1, 2, 0])
g
# Out:
# TransferFunction(array([4]), array([1, 2, 0]))

# %%
r=rlocus(g, plot=True)
figure(1),clf
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>, <function matplotlib.pyplot.clf()>)

# %%
gc = tf([4], [1, 2, 4])
gcc=tf([4.076,0.4076],[1,2.02,4.116,0.4076])
figure(2),clf
t,y=step_response(gc)
t2,y2=step_response(gcc)
plot(t,y)
plot(t2,y2,'--')
title("Sys_openloop")
grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Sistema Compensado
# $G(s)G_c(s)=\frac{16s+32}{s^3+6s^2+24s+32}$

# %%
ggc=tf([16,32],[1,6,24,32])

figure(2),clf
t,y=step_response(ggc)
figure(3),clf()
plot(t,y)
title("Sys_openloop")
grid()
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
r=rlocus(gcc, plot=True)

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 0 Axes>, <function matplotlib.pyplot.clf()>)
